# %%
import pandas as pd
import matplotlib.pyplot as plt
import string
printable = set(string.printable)
from tqdm.notebook import tqdm
import wikipedia
import spacy
import json
import tqdm

from spacy import displacy
nlp = spacy.load('en_core_web_sm', exclude='ner')

from spacy.matcher import Matcher 
from spacy.tokens import Span 
from spacy.pipeline import EntityRuler
from spacy.language import Language

import networkx as nx
import glob

# %%
with open('sample2.json') as f:
    data = json.load(f)

# %%
ruler = EntityRuler(nlp, overwrite_ents=True)
patterns = data
ruler.add_patterns(patterns)

@Language.component('ent_ruler')
def ent_ruler(doc):
    ruler(doc)
    return doc

if 'ent_ruler' in nlp.pipe_names:
    nlp.remove_pipe('ent_ruler')
    
nlp.add_pipe('ent_ruler')
# Out:
# <function __main__.ent_ruler(doc)>

# %%
genres = pd.read_csv('imdb_with_wiki.csv')['genre']

dataset = pd.unique(genres.dropna())
temp = []
    
for i in range(len(dataset)):
    temp += dataset[i].lower().split(", ")

genres = list(set(temp))
genres.append('science fiction')

# %%
matcher = Matcher(nlp.vocab)
pattern = [
    [{"LEMMA": {"IN": ["write", "direct", "director", "writor"]}} ],
    ]

matcher.add("matching", pattern)

# %%
def get_edges(title):
    with open(r'Movies/'+str(title)+'.txt') as f:
        content = f.read()
    
    content = content.split('==')
    
    title = [(title, 'title')]
    cast = []
    genre = []
    director = []
    writer = []
    plot = []
    drt_wrt = []
    producer = []
    award = []
    
    dict1 = {}
    for i in range(1,len(content),2):
        key = content[i][1:-1]
        dict1[key.lower()] = content[i+1]
      
    #Cast
    try:
        casting = dict1['cast'].split('\n')
        casting = [i for i in casting if i != '']
        
        for i in casting:
            cast.append((i.split(' as ')[0], 'cast')) 
    except:
        None
        
    #Plot
    try:
        temp = dict1['plot'].replace('\n', '')
        plot.append((temp, 'plot'))
    except:
        None

    #Production
    try:
        temp = dict1['production'].replace('\n', '')
        producer.append((temp, 'producer'))
    except:
        None

    
                
    for sent in  content[0].split('.'):
        doc = nlp(sent)

        matches = matcher(doc)
        edges = []
        ents = []

        for i in range(len(matches)):
            if doc[matches[i][1]:matches[i][2]].text.find('writ') != -1:
                edges.append('writer')
            else:
                edges.append('director')


        for ent in doc.ents:
            if ent.label_ == 'GNR':
                genre.append((ent.text, 'genre'))
            if ent.label_ in ['WRT','DRT']:
                ents.append(ent.text)

        for i in range(len(ents)):
            try:
                drt_wrt.append((ents[i], edges[i]))
            except:
                drt_wrt.append((ents[i], edges[-1]))

        if sent.find('award') != -1:
            award.append((sent, 'award'))

        

    KG_edges = cast + genre + drt_wrt + plot + producer + award
    return KG_edges

# %%
edges = get_edges('Atlantis')

# %%
def build_graph(directory):
    Graph = nx.Graph()
    index = 0
    flist = glob.glob(str(directory)+'\*')
    
    for file in flist:
        title = file[7:-4]
        edges = get_edges(title)
        
        for edge in edges:
            if edge[1] in ['producer', 'plot', 'award']:
                Graph.add_edge(title, index, relation=edge[1])
                Graph.nodes.data()[index]['content'] = edge[0]
                index += 1
            else:
                Graph.add_edge(title, edge[0], relation=edge[1])
    return Graph

# %%
KG = build_graph('Deneme')

# %%
nx.write_gexf(KG, "Knowledge_Graph.gexf")

# %%
KG.edges.data()
# Out:
# EdgeDataView([('Atlantic', 'graham greene', {'relation': 'cast'}), ('Atlantic', 'david chokachi', {'relation': 'cast'}), ('Atlantic', 'treach', {'relation': 'cast'}), ('Atlantic', 'jackie moore', {'relation': 'cast'}), ('Atlantic', 'nicole alexandra shipley', {'relation': 'cast'}), ('Atlantic', 'jared cohn', {'relation': 'cast'}), ('Atlantic', 'jinhi evans', {'relation': 'cast'}), ('Atlantic', 'steven marlow', {'relation': 'cast'}), ('Atlantic', 'nicole dickson', {'relation': 'cast'}), ('Atlantic', 'demetrius stear', {'relation': 'cast'}), ('Atlantic', 'larry gamell, jr.', {'relation': 'cast'}), ('Atlantic', 'william shannon williams', {'relation': 'cast'}), ('Atlantic', 'joseph brown', {'relation': 'cast'}), ('Atlantic', 0, {'relation': 'plot'}), ('Atlantic', 1, {'relation': 'producer'})])

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(KG)
nx.draw(KG, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
